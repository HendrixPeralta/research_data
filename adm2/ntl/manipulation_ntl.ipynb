# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import plotly.express as px

# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.31.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
ntl = pd.read_csv("sum_ntl_adm2_2000_2021.csv")

# %%
ntl_mean = pd.read_csv("mean_ntl_adm2_2000_2021.csv")

# %%
fig = px.box(ntl, x = "shapeName", y = "total_sol")
fig.update_xaxes(categoryorder='total descending')
fig.show()

# %%
ntl_wide = ntl_mean.pivot(index = ["id", "shapeName"], columns = "year", values = "total_sol")

# %%
ntl_sum_wide = ntl_wide.add_prefix("ntl_")

# %%
ntl_sum_wide.columns
# Out:
# Index(['ntl_2000', 'ntl_2001', 'ntl_2002', 'ntl_2003', 'ntl_2004', 'ntl_2005',
#        'ntl_2006', 'ntl_2007', 'ntl_2008', 'ntl_2009', 'ntl_2010', 'ntl_2011',
#        'ntl_2012', 'ntl_2013', 'ntl_2014', 'ntl_2015', 'ntl_2016', 'ntl_2017',
#        'ntl_2018', 'ntl_2019', 'ntl_2020', 'ntl_2021', 'ntl_2022'],
#       dtype='object', name='year')

# %%
#ntl_sum_wide.to_csv("ntl_sum_wide_00-22.csv")

# %%
ntl_wide_reset = ntl_wide.reset_index()  # Reset the index
ntl_00and16 = ntl_wide_reset[[2000, 2016, "id"]]  # Select columns including "id"

# %%
#ntl_00and16.to_csv('2000and2016.csv', index=False)

# %%
# Out:
# year      2000      2016   id
# 0     1.049457  1.261424    1
# 1     1.012013  1.054829    2
# 2     1.218282  3.052055    3
# 3     1.008230  1.047437    4
# 4     1.007903  1.168871    5
# ..         ...       ...  ...
# 157   1.000000  1.000000  158
# 158   1.000000  1.000000  159
# 159   1.534750  4.067744  160
# 160   1.188298  2.265729  161
# 161   1.020293  1.399016  162
#
# [162 rows x 3 columns]
