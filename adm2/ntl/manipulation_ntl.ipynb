# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import plotly.express as px

# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.31.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
ntl = pd.read_csv("sum_ntl_adm2_2000_2021.csv")

# %%
ntl_mean = pd.read_csv("mean_ntl_adm2_2000_2021.csv")

# %%
fig = px.box(ntl, x = "shapeName", y = "total_sol")
fig.update_xaxes(categoryorder='total descending')
fig.show()

# %%
ntl_wide = ntl_mean.pivot(index = ["id", "shapeName"], columns = "year", values = "total_sol")

# %%
ntl_wide.head()
# Out:
# year                     2000      2001      2002      2003      2004  \
# id shapeName
# 0  Constanza         0.049457  0.078925  0.102329  0.070205  0.066728
# 1  Sabana De La Mar  0.012013  0.020921  0.032937  0.012745  0.029467
# 2  Moca              0.218282  0.203814  0.551070  0.465303  0.456324
# 3  Bayaguana         0.008230  0.012819  0.053092  0.027037  0.018702
# 4  El Factor         0.007903  0.024457  0.058619  0.000000  0.001966
#
# year                     2005      2006      2007      2008      2009  ...  \
# id shapeName                                                           ...
# 0  Constanza         0.056932  0.079726  0.081665  0.054235  0.068892  ...
# 1  Sabana De La Mar  0.013155  0.018164  0.013462  0.008532  0.017813  ...
# 2  Moca              0.231695  0.339829  0.221490  0.268126  0.359653  ...
# 3  Bayaguana         0.009461  0.010758  0.004520  0.007137  0.004743  ...
# 4  El Factor         0.000000  0.002588  0.000702  0.000000  0.000000  ...
#
# year                     2013      2014      2015      2016      2017  \
# id shapeName
# 0  Constanza         0.163717  0.199235  0.275266  0.261424  0.266472
# 1  Sabana De La Mar  0.052045  0.058413  0.064734  0.054829  0.059540
# 2  Moca              1.514305  1.899313  2.090571  2.052055  2.450457
# 3  Bayaguana         0.027539  0.028921  0.019717  0.047437  0.071559
# 4  El Factor         0.169288  0.174950  0.173296  0.168871  0.269597
#
# year                     2018      2019      2020      2021      2022
# id shapeName
# 0  Constanza         0.241848  0.313275  0.452059  0.507187  0.494288
# 1  Sabana De La Mar  0.073573  0.080247  0.084166  0.100997  0.107075
# 2  Moca              2.539096  2.935329  2.995491  3.625937  4.142743
# 3  Bayaguana         0.065549  0.066805  0.068614  0.099964  0.106104
# 4  El Factor         0.250877  0.290998  0.366983  0.586179  1.130638
#
# [5 rows x 23 columns]

# %%
ntl_2000 = ntl_wide[2000]

# %%
ntl_2000.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 162 entries, 0 to 161
# Series name: 2016
# Non-Null Count  Dtype
# --------------  -----
# 162 non-null    float64
# dtypes: float64(1)
# memory usage: 2.5 KB

# %%
ntl_2016 = ntl_wide[2016]

# %%
ntl_00and16 = pd.concat([ntl_2000, ntl_2016], axis = 1).add_prefix("ntl_")

# %%
ntl_00and16.to_csv('2000and2016.csv', index=False)
