# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.31.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
ntl = pd.read_csv("sum_ntl_adm2_2000_2021.csv")
ntl_mean = pd.read_csv("mean_ntl_adm2_2000_2021.csv")

# %%
fig = px.box(ntl, x = "shapeName", y = "total_sol")
fig.update_xaxes(categoryorder='total descending')
fig.show()
# Out:
# <div>                            <div id="6a63c315-deab-4f08-9a7d-3b3df967ec02" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a63c315-deab-4f08-9a7d-3b3df967ec02")) {                    Plotly.newPlot(                        "6a63c315-deab-4f08-9a7d-3b3df967ec02",                        [{"alignmentgroup":"True","hovertemplate":"shapeName=%{x}\u003cbr\u003etotal_sol=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Constanza","Sabana De La Mar","Moca","Bayaguana","El Factor","San Francisco De Macor\u00eds","Puerto Plata","Jamao Al Norte","Las Matas de Santa Cruz","Jiman\u00ed","Ban\u00ed","Villa Hermosa","El Cercado","Eu
# ...

# %%
ntl_wide = ntl_mean.pivot(index = ["id", "shapeName"], columns = "year", values = "total_sol")
ntl_sum_wide = ntl_wide.add_prefix("ntl_")
ntl_sum_wide.columns
ntl_wide_reset = ntl_wide.reset_index()  # Reset the index

# %%
ntl_sum_wide.to_csv("ntl_sum_wide_00-22.csv")

# %%
ntl_wide_reset = ntl_wide.reset_index()  # Reset the index
ntl_00and16 = ntl_wide_reset[[2000, 2016, "id"]]  # Select columns including "id"

# %%
#ntl_00and16.to_csv('2000and2016.csv', index=False)
